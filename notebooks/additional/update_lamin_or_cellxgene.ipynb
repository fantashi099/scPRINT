# %%
# update lamindb and bionty...

# %%
! lamin load scprint
# Out:
# → connected lamindb: jkobject/scprint

# %%
! lamin migrate deploy
# Out:
# Operations to perform:
#   Apply all migrations: bionty, lnschema_core
# Running pre-migrate handlers for application lnschema_core
# Running pre-migrate handlers for application bionty
# Running migrations:
#   Applying lnschema_core.0065_remove_collection_feature_sets_and_more... OK (1.386s)
#   Applying lnschema_core.0066_alter_artifact__feature_values_and_more... OK (3.067s)
#   Applying bionty.0038_alter_artifactcellline_created_by_and_more... OK (4.517s)
#   Applying bionty.0039_alter_cellline_source_alter_cellmarker_source_and_more... OK (1.847s)
# Running post-migrate handlers for application lnschema_core
# Running post-migrate handlers for application bionty

# %% [markdown]
# # we will check it works and reset the bionty sources

# %%
import lamindb as ln
import bionty as bt
from scdataloader.utils import populate_my_ontology
# %load_ext autoreload
# %autoreload 2
# Out:
# → connected lamindb: jkobject/scprint

# %%
len(ln.Artifact.filter())
# Out:
# 0

# %%
bt.base.reset_sources()

# %%
bt.core.sync_all_sources_to_latest()
# Out:
# ! please reload your instance to reflect the updates!

# %% [markdown]
# # load them in my personnal ontology

# %%
bt.DevelopmentalStage.artifacts.through.objects.all().delete()
bt.DevelopmentalStage.filter().delete()

# %%
#bt.Tissue.import_from_source() 
bt.DevelopmentalStage.import_from_source()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[41], line 2
#       1 #bt.Tissue.import_from_source()
# ----> 2 bt.DevelopmentalStage.import_from_source()
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/bionty/models.py:266, in BioRecord.import_from_source(cls, source, ontology_ids, organism, ignore_conflicts, update)
#     263 from .core._add_ontology import add_ontology_from_df, check_source_in_db
#     265 if hasattr(cls, "ontology_id"):
# --> 266     add_ontology_from_df(
#     267         registry=cls,
#     268         ontology_ids=ontology_ids,
#     269         organism=organism,
#     270         source=source,
#     271         ignore_conflicts=ignore_conflicts,
#     272         update=update,
#     273     )
#     274 else:
#     275     import lamindb as ln
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/bionty/core/_add_ontology.py:146, in add_ontology_from_df(registry, ontology_ids, organism, source, ignore_conflicts, update)
#     142 import lamindb as ln
#     144 from bionty._bionty import get_source_record
# --> 146 public = registry.public(organism=organism, source=source)
#     147 df = prepare_dataframe(public.df())
#     149 # TODO: consider StaticReference
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/bionty/models.py:394, in BioRecord.public(cls, organism, source)
#     391     version = None
#     393 try:
# --> 394     return getattr(bionty_base, cls.__name__)(
#     395         organism=organism, source=source_name, version=version
#     396     )
#     397 except (AttributeError, ValueError):
#     398     if source is None:
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/bionty/base/entities/_developmentalstage.py:26, in DevelopmentalStage.__init__(self, organism, source, version, **kwargs)
#      19 def __init__(
#      20     self,
#      21     organism: Optional[Literal["human", "mouse"]] = None,
#    (...)
#      24     **kwargs,
#      25 ) -> None:
# ---> 26     super().__init__(
#      27         source=source,
#      28         version=version,
#      29         organism=organism,
#      30         include_id_prefixes={"hsapdv": ["HsapDv"], "mmusdv": ["MmusDv"]},
#      31         include_rel="part_of",
#      32         **kwargs,
#      33     )
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/bionty/base/_public_ontology.py:56, in PublicOntology.__init__(self, source, version, organism, include_id_prefixes, include_rel)
#      46 def __init__(
#      47     self,
#      48     source: str | None = None,
#    (...)
#      53     include_rel: str | None = None,
#      54 ):
#      55     try:
# ---> 56         self._fetch_sources()
#      57         try:
#      58             # match user input organism, source and version with currently used sources
#      59             current = self._match_sources(
#      60                 self._current_sources,
#      61                 source=source,
#      62                 version=version,
#      63                 organism=organism,
#      64             )
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/bionty/base/_public_ontology.py:177, in PublicOntology._fetch_sources(self)
#     173 def _subset_to_entity(df: pd.DataFrame, key: str):
#     174     return df.loc[[key]] if isinstance(df.loc[key], pd.Series) else df.loc[key]
#     176 self._current_sources = _subset_to_entity(
# --> 177     display_currently_used_sources(), self.__class__.__name__
#     178 )
#     180 self._all_sources = _subset_to_entity(
#     181     display_available_sources(), self.__class__.__name__
#     182 )
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/bionty/base/_display_sources.py:38, in display_currently_used_sources()
#      24 """Displays all currently used sources.
#      25
#      26 Active version is unique for entity + organism.
#    (...)
#      30     >>> bt.display_currently_used_sources()
#      31 """
#      32 VERSIONS_FILE_PATH = (
#      33     settings.lamindb_sources
#      34     if LAMINDB_INSTANCE_LOADED()
#      35     else settings.current_sources
#      36 )
# ---> 38 versions = load_yaml(VERSIONS_FILE_PATH.resolve())
#      40 df_rows = []
#      41 for bionty_class, bionty_class_data in versions.items():
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/bionty/base/dev/_io.py:15, in load_yaml(filename, convert_dates)
#      12 def load_yaml(
#      13     filename: Union[str, Path], convert_dates: bool = True
#      14 ):  # pragma: no cover
# ---> 15     with open(filename) as f:
#      16         return yaml.safe_load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ml4ig1/.lamin/bionty/versions/.lamindb_current_sources.yaml'

# %%
bt.DevelopmentalStage.public().df().loc["HsapDv:0000144"].parents
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 bt.DevelopmentalStage.public().df().loc["HsapDv:0000144"].parents
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/bionty/models.py:394, in BioRecord.public(cls, organism, source)
#     391     version = None
#     393 try:
# --> 394     return getattr(bionty_base, cls.__name__)(
#     395         organism=organism, source=source_name, version=version
#     396     )
#     397 except (AttributeError, ValueError):
#     398     if source is None:
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/bionty/base/entities/_developmentalstage.py:26, in DevelopmentalStage.__init__(self, organism, source, version, **kwargs)
#      19 def __init__(
#      20     self,
#      21     organism: Optional[Literal["human", "mouse"]] = None,
#    (...)
#      24     **kwargs,
#      25 ) -> None:
# ---> 26     super().__init__(
#      27         source=source,
#      28         version=version,
#      29         organism=organism,
#      30         include_id_prefixes={"hsapdv": ["HsapDv"], "mmusdv": ["MmusDv"]},
#      31         include_rel="part_of",
#      32         **kwargs,
#      33     )
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/bionty/base/_public_ontology.py:56, in PublicOntology.__init__(self, source, version, organism, include_id_prefixes, include_rel)
#      46 def __init__(
#      47     self,
#      48     source: str | None = None,
#    (...)
#      53     include_rel: str | None = None,
#      54 ):
#      55     try:
# ---> 56         self._fetch_sources()
#      57         try:
#      58             # match user input organism, source and version with currently used sources
#      59             current = self._match_sources(
#      60                 self._current_sources,
#      61                 source=source,
#      62                 version=version,
#      63                 organism=organism,
#      64             )
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/bionty/base/_public_ontology.py:177, in PublicOntology._fetch_sources(self)
#     173 def _subset_to_entity(df: pd.DataFrame, key: str):
#     174     return df.loc[[key]] if isinstance(df.loc[key], pd.Series) else df.loc[key]
#     176 self._current_sources = _subset_to_entity(
# --> 177     display_currently_used_sources(), self.__class__.__name__
#     178 )
#     180 self._all_sources = _subset_to_entity(
#     181     display_available_sources(), self.__class__.__name__
#     182 )
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/bionty/base/_display_sources.py:38, in display_currently_used_sources()
#      24 """Displays all currently used sources.
#      25
#      26 Active version is unique for entity + organism.
#    (...)
#      30     >>> bt.display_currently_used_sources()
#      31 """
#      32 VERSIONS_FILE_PATH = (
#      33     settings.lamindb_sources
#      34     if LAMINDB_INSTANCE_LOADED()
#      35     else settings.current_sources
#      36 )
# ---> 38 versions = load_yaml(VERSIONS_FILE_PATH.resolve())
#      40 df_rows = []
#      41 for bionty_class, bionty_class_data in versions.items():
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/bionty/base/dev/_io.py:15, in load_yaml(filename, convert_dates)
#      12 def load_yaml(
#      13     filename: Union[str, Path], convert_dates: bool = True
#      14 ):  # pragma: no cover
# ---> 15     with open(filename) as f:
#      16         return yaml.safe_load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ml4ig1/.lamin/bionty/versions/.lamindb_current_sources.yaml'

# %%
# we have a match between the sources

# %%
bt.DevelopmentalStage.filter().df(include=["parents__ontology_id"]).set_index("ontology_id").loc["HsapDv:0000144"].parents__ontology_id
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HsapDv:0000144'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 bt.DevelopmentalStage.filter().df(include=["parents__ontology_id"]).set_index("ontology_id").loc["HsapDv:0000144"].parents__ontology_id
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/pandas/core/generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'HsapDv:0000144'

# %%
source = bt.PublicSource.filter(organism="mouse", name="mmusdv").last()

# %%
bt.DevelopmentalStage.import_from_source(source=source)

# %%
# delete all old artifacts
bt.Tissue.artifacts.through.objects.all().delete()
bt.Tissue.filter().delete()
bt.Disease.artifacts.through.objects.all().delete()
bt.Disease.filter().delete()
bt.CellType.artifacts.through.objects.all().delete()
bt.CellType.filter().delete()
bt.ExperimentalFactor.artifacts.through.objects.all().delete()
bt.ExperimentalFactor.filter().delete()
bt.Ethnicity.artifacts.through.objects.all().delete()
bt.Ethnicity.filter().delete()

# %%
# more straightforward
populate_my_ontology(organisms=["NCBITaxon:9544", "NCBITaxon:9483", "NCBITaxon:10090", "NCBITaxon:9606"])
# Out:
# → returning existing Organism record with same name: 'unknown'
# → returning existing Phenotype record with same name: 'unknown'
# ! record with similar name exists! did you mean to load it?
#             uid                     name  ontology_id  abbr  \
# id
# 21073  63btPuBB  fever of unknown origin  EFO:0003952  None
#
#                                          synonyms  \
# id
# 21073  Unknown Origin Fever|Unknown Origin Fevers
#
#                                              description molecule instrument  \
# id
# 21073  Fever In Which The Etiology Cannot Be Ascertai...     None       None
#
#       measurement  source_id run_id  created_by_id  \
# id
# 21073        None         78   None              1
#
#                             updated_at
# id
# 21073 2024-09-12 12:22:42.173128+00:00
# ! DevelopmentalStage records from source (hsapdv, 2024-05-28) are already in the database!
#    → pass `update=True` to update the records
# ! DevelopmentalStage records from source (mmusdv, 2024-05-28) are already in the database!
#    → pass `update=True` to update the records
# → returning existing DevelopmentalStage record with same name: 'unknown'
# ! records with similar names exist! did you mean to load one of them?
#             uid                                               name  \
# id
# 27075  7CKxLDlu                    obsolete congenital abnormality
# 27117  5pHdg2Ic  obsolete myeloid and lymphoid neoplasms with e...
# 27120  5lzQM8ub  myeloid and lymphoid neoplasms associated with...
#
#          ontology_id  abbr                                           synonyms  \
# id
# 27075  MONDO:0000839  None  congenital abnormality|congenital anatomic Abn...
# 27117  MONDO:0000881  None                                               None
# 27120  MONDO:0000884  None                                               None
#
#                                              description  source_id run_id  \
# id
# 27075  Obsolete. Any Abnormality, Anatomical Or Bioch...         69   None
# 27117                                               None         69   None
# 27120                                               None         69   None
#
#        created_by_id                       updated_at
# id
# 27075              1 2024-09-12 12:22:55.501725+00:00
# 27117              1 2024-09-12 12:22:55.504418+00:00
# 27120              1 2024-09-12 12:22:55.504609+00:00
# ! records with similar names exist! did you mean to load one of them?
#             uid                                               name  \
# id
# 33941  1wpjcCa5  hemoglobin--variants for which the chain carry...
# 42811  2C05jMg9    sporadic adult-onset ataxia of unknown etiology
# 42924  4sqESY3D  obsolete glial tumor of neuroepithelial tissue...
#
#          ontology_id  abbr                                      synonyms  \
# id
# 33941  MONDO:0007717  None                                          None
# 42811  MONDO:0016591  None  SAOA|idiopathic late-onset cerebellar ataxia
# 42924  MONDO:0016704  None                                          None
#
#                                              description  source_id run_id  \
# id
# 33941                                               None         69   None
# 42811  Sporadic Adult-Onset Ataxia Of Unknown Etiolog...         69   None
# 42924                                               None         69   None
#
#        created_by_id                       updated_at
# id
# 33941              1 2024-09-12 12:22:56.435466+00:00
# 42811              1 2024-09-12 12:22:57.181985+00:00
# 42924              1 2024-09-12 12:22:57.190972+00:00

# %%
list(bt.Disease.filter(ontology_id="MONDO:0000005").one().parents.filter())
# Out:
# [Disease(uid='4oYaDnBG', name='alopecia', ontology_id='MONDO:0004907', synonyms='alopecia|hair loss|loss Of hair', description='Hair Loss Usually From The Scalp. It May Result In Bald Spots Or Spread To The Entire Scalp Or The Entire Epidermis. It May Be Androgenetic Or Caused By Chemotherapeutic Agents, Compulsive Hair Pulling, Autoimmune Disorders Or Congenital Conditions.', created_by_id=1, source_id=69, updated_at='2024-09-12 12:22:56 UTC'),
#  Disease(uid='1KQgvwK8', name='hereditary skin disorder', ontology_id='MONDO:0100118', synonyms='genodermatosis|diseases, genetic skin|skin disease, genetic|genetic skin diseases|disease, genetic skin|genetic skin disease', description='An Instance Of Skin Disease That Is Caused By A Modification Of The Individual'S Genome.', created_by_id=1, source_id=69, updated_at='2024-09-12 12:22:58 UTC')]

# %%
bt.Disease.public().df().loc["MONDO:0000005"].parents
# Out:
# array(['MONDO:0100118', 'MONDO:0004907'], dtype=object)

# %% [markdown]
# # load the latest datasets / load datasets that were initially dropped

# %%
list(ln.Collection.using(instance="laminlabs/cellxgene").filter(name="cellxgene-census").all())
# Out:
# [Collection(uid='dMyEX3NTfKOEYXyMu591', version='2023-12-15', is_latest=False, name='cellxgene-census', hash='0NB32iVKG5ttaW5XILvG', visibility=1, created_by_id=1, transform_id=19, run_id=24, updated_at='2024-01-30 09:09:49 UTC'),
#  Collection(uid='dMyEX3NTfKOEYXyMKDAQ', version='2023-07-25', is_latest=False, name='cellxgene-census', hash='pEJ9uvIeTLvHkZW2TBT5', visibility=1, created_by_id=1, transform_id=18, run_id=23, updated_at='2024-01-30 09:06:05 UTC'),
#  Collection(uid='dMyEX3NTfKOEYXyMKDD7', version='2024-07-01', is_latest=True, name='cellxgene-census', hash='nI8Ag-HANeOpZOz-8CSn', visibility=1, created_by_id=1, transform_id=22, run_id=27, updated_at='2024-07-16 12:24:38 UTC')]

# %%
cx_dataset = ln.Collection.using(instance="laminlabs/cellxgene").filter(name="cellxgene-census", version='2024-07-01').one()
cx_dataset, len(cx_dataset.artifacts.all())
# Out:
# ! no run & transform get linked, consider calling ln.context.track()
# (Collection(uid='dMyEX3NTfKOEYXyMKDD7', version='2024-07-01', is_latest=True, name='cellxgene-census', hash='nI8Ag-HANeOpZOz-8CSn', visibility=1, created_by_id=1, transform_id=22, run_id=27, updated_at='2024-07-16 12:24:38 UTC'),
#  812)

# %%
cx_dataset_2 = ln.Collection.using(instance="laminlabs/cellxgene").filter(name="cellxgene-census", version='2023-12-15').one()
cx_dataset_2, len(cx_dataset_2.artifacts.all())
# Out:
# ! renewing expired lamin token: call `lamin login` to avoid this
# ! no run & transform get linked, consider calling ln.context.track()
# (Collection(uid='dMyEX3NTfKOEYXyMu591', version='2023-12-15', is_latest=False, name='cellxgene-census', hash='0NB32iVKG5ttaW5XILvG', visibility=1, created_by_id=1, transform_id=19, run_id=24, updated_at='2024-01-30 09:09:49 UTC'),
#  1113)

# %%
cx_dataset.artifacts.all()[0].key
# Out:
# ! no run & transform get linked, consider calling ln.context.track()
# 'cell-census/2024-07-01/h5ads/0041b9c3-6a49-4bf7-8514-9bc7190067a7.h5ad'

# %%
cx_dataset.artifacts.all()[0].key.split("/")[-1]
# Out:
# ! no run & transform get linked, consider calling ln.context.track()
# '0041b9c3-6a49-4bf7-8514-9bc7190067a7.h5ad'

# %%
len(set([a.key.split("/")[-1] for a in cx_dataset.artifacts.all()]) - set([a.key.split("/")[-1] for a in cx_dataset_2.artifacts.all()]))
# Out:
# ! no run & transform get linked, consider calling ln.context.track()
# ! no run & transform get linked, consider calling ln.context.track()
# 129

# %%
len(set([a.key.split("/")[-1] for a in cx_dataset.artifacts.all()]) & set([a.key.split("/")[-1] for a in cx_dataset_2.artifacts.all()]))
# Out:
# ! no run & transform get linked, consider calling ln.context.track()
# ! no run & transform get linked, consider calling ln.context.track()
# 683

# %%
a = set([a.key.split("/")[-1] for a in cx_dataset_2.artifacts.all()]) - set([a.key.split("/")[-1] for a in cx_dataset.artifacts.all()])
a = list(a)
len(a)
# Out:
# ! no run & transform get linked, consider calling ln.context.track()
# ! no run & transform get linked, consider calling ln.context.track()
# 430

# %%
cx_dataset_2.artifacts.filter(key="cell-census/2023-12-15/h5ads/"+a[20]).one().description
# Out:
# 'Joint scRNA-seq and scATAC-seq atlas of the adult human retina'

# %%
from scdataloader.preprocess import (
    LaminPreprocessor,
    additional_postprocess,
    additional_preprocess,
)

DESCRIPTION='scPRINT-V2 datasets'


do_preprocess = LaminPreprocessor(additional_postprocess=additional_postprocess, additional_preprocess=additional_preprocess, skip_validate=False, subset_hvg=3000, cache=False, stream=True, filter_gene_by_counts=False, filter_cell_by_counts=500, min_valid_genes_id=4000, min_nnz_genes=150, maxdropamount=90, organisms=["NCBITaxon:9606", "NCBITaxon:9544", "NCBITaxon:9483", "NCBITaxon:10090"], batch_key="assay_ontology_term_id")

# %%
preprocessed_dataset = do_preprocess(cx_dataset_2, name=DESCRIPTION, description=DESCRIPTION, start_at=13, version="3")
# Out:
# ! no run & transform get linked, consider calling ln.context.track()
# 13
# Artifact(uid='R4ZHoQegxXdSFNFYJ146', version='2023-12-15', is_latest=False, description='A proximal-to-distal survey of healthy adult human small intestine and colon epithelium by single-cell transcriptomics', key='cell-census/2023-12-15/h5ads/019c7af2-c827-4454-9970-44d5e39ce068.h5ad', suffix='.h5ad', size=1746683238, hash='5JSpfZdzeM1Tlicvx6-A0g', n_observations=12590, _hash_type='md5-n', _accessor='AnnData', visibility=1, _key_is_virtual=False, created_by_id=1, storage_id=2, transform_id=16, run_id=22, updated_at='2024-01-29 07:45:47 UTC')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 preprocessed_dataset = do_preprocess(cx_dataset_2, name=DESCRIPTION, description=DESCRIPTION, start_at=13, version="3")
#
# File ~/Documents code/scDataLoader/scdataloader/preprocess.py:447, in LaminPreprocessor.__call__(self, data, name, description, start_at, version)
#     445     continue
#     446 if file.size <= MAXFILESIZE:
# --> 447     adata = file.load(stream=self.stream)
#     448     print(adata)
#     449 else:
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/lamindb/_artifact.py:967, in load(self, is_run_input, stream, **kwargs)
#     965 else:
#     966     using_key = settings._using_key
# --> 967     access_memory = load_to_memory(
#     968         filepath_from_artifact(self, using_key=using_key), stream=stream, **kwargs
#     969     )
#     970 # only call if load is successfull
#     971 _track_run_input(self, is_run_input)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/lamindb/core/storage/paths.py:245, in load_to_memory(filepath, stream, **kwargs)
#     243     return filepath
#     244 else:
# --> 245     return reader(filepath, **kwargs)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/lamindb/core/storage/paths.py:109, in read_adata_h5ad(filepath, **kwargs)
#     106 fs, filepath = infer_filesystem(filepath)
#     108 with fs.open(filepath, mode="rb") as file:
# --> 109     adata = ad.read_h5ad(file, backed=False, **kwargs)
#     110     return adata
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/anndata/_io/h5ad.py:261, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     258         return read_dataframe(elem)
#     259     return func(elem)
# --> 261 adata = read_dispatched(f, callback=callback)
#     263 # Backwards compat (should figure out which version)
#     264 if "raw.X" in f:
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/anndata/experimental/_dispatch_io.py:48, in read_dispatched(elem, callback)
#      44 from anndata._io.specs import _REGISTRY, Reader
#      46 reader = Reader(_REGISTRY, callback=callback)
# ---> 48 return reader.read_elem(elem)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/anndata/_io/utils.py:207, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     205     raise ValueError("No element found in args.")
#     206 try:
# --> 207     return func(*args, **kwargs)
#     208 except Exception as e:
#     209     path, key = _get_display_path(store).rsplit("/", 1)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/anndata/_io/specs/registry.py:256, in Reader.read_elem(self, elem, modifiers)
#     254 if self.callback is None:
#     255     return read_func(elem)
# --> 256 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/anndata/_io/h5ad.py:242, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     239 def callback(func, elem_name: str, elem, iospec):
#     240     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#     241         return AnnData(
# --> 242             **{
#     243                 # This is covering up backwards compat in the anndata initializer
#     244                 # In most cases we should be able to call `func(elen[k])` instead
#     245                 k: read_dispatched(elem[k], callback)
#     246                 for k in elem.keys()
#     247                 if not k.startswith("raw.")
#     248             }
#     249         )
#     250     elif elem_name.startswith("/raw."):
#     251         return None
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/anndata/_io/h5ad.py:245, in <dictcomp>(.0)
#     239 def callback(func, elem_name: str, elem, iospec):
#     240     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#     241         return AnnData(
#     242             **{
#     243                 # This is covering up backwards compat in the anndata initializer
#     244                 # In most cases we should be able to call `func(elen[k])` instead
# --> 245                 k: read_dispatched(elem[k], callback)
#     246                 for k in elem.keys()
#     247                 if not k.startswith("raw.")
#     248             }
#     249         )
#     250     elif elem_name.startswith("/raw."):
#     251         return None
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/anndata/experimental/_dispatch_io.py:48, in read_dispatched(elem, callback)
#      44 from anndata._io.specs import _REGISTRY, Reader
#      46 reader = Reader(_REGISTRY, callback=callback)
# ---> 48 return reader.read_elem(elem)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/anndata/_io/utils.py:207, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     205     raise ValueError("No element found in args.")
#     206 try:
# --> 207     return func(*args, **kwargs)
#     208 except Exception as e:
#     209     path, key = _get_display_path(store).rsplit("/", 1)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/anndata/_io/specs/registry.py:256, in Reader.read_elem(self, elem, modifiers)
#     254 if self.callback is None:
#     255     return read_func(elem)
# --> 256 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/anndata/_io/h5ad.py:259, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     256 elif elem_name in {"/obs", "/var"}:
#     257     # Backwards compat
#     258     return read_dataframe(elem)
# --> 259 return func(elem)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/anndata/_io/specs/methods.py:604, in read_sparse(elem, _reader)
#     599 @_REGISTRY.register_read(H5Group, IOSpec("csc_matrix", "0.1.0"))
#     600 @_REGISTRY.register_read(H5Group, IOSpec("csr_matrix", "0.1.0"))
#     601 @_REGISTRY.register_read(ZarrGroup, IOSpec("csc_matrix", "0.1.0"))
#     602 @_REGISTRY.register_read(ZarrGroup, IOSpec("csr_matrix", "0.1.0"))
#     603 def read_sparse(elem, _reader):
# --> 604     return sparse_dataset(elem).to_memory()
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/anndata/_core/sparse_dataset.py:532, in BaseCompressedSparseDataset.to_memory(self)
#     530 format_class = get_memory_class(self.format)
#     531 mtx = format_class(self.shape, dtype=self.dtype)
# --> 532 mtx.data = self.group["data"][...]
#     533 mtx.indices = self.group["indices"][...]
#     534 mtx.indptr = self.indptr
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/h5py/_hl/dataset.py:758, in Dataset.__getitem__(self, args, new_dtype)
#     756 if self._fast_read_ok and (new_dtype is None):
#     757     try:
# --> 758         return self._fast_reader.read(args)
#     759     except TypeError:
#     760         pass  # Fall back to Python read pathway below
#
# File h5py/_selector.pyx:376, in h5py._selector.Reader.read()
#
# File h5py/h5fd.pyx:163, in h5py.h5fd.H5FD_fileobj_read()
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/fsspec/spec.py:1959, in AbstractBufferedFile.readinto(self, b)
#    1954 """mirrors builtin file's readinto method
#    1955
#    1956 https://docs.python.org/3/library/io.html#io.RawIOBase.readinto
#    1957 """
#    1958 out = memoryview(b).cast("B")
# -> 1959 data = self.read(out.nbytes)
#    1960 out[: len(data)] = data
#    1961 return len(data)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/fsspec/spec.py:1941, in AbstractBufferedFile.read(self, length)
#    1938 if length == 0:
#    1939     # don't even bother calling fetch
#    1940     return b""
# -> 1941 out = self.cache._fetch(self.loc, self.loc + length)
#    1943 logger.debug(
#    1944     "%s read: %i - %i %s",
#    1945     self,
#    (...)
#    1948     self.cache._log_stats(),
#    1949 )
#    1950 self.loc += len(out)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/fsspec/caching.py:234, in ReadAheadCache._fetch(self, start, end)
#     232 end = min(self.size, end + self.blocksize)
#     233 self.total_requested_bytes += end - start
# --> 234 self.cache = self.fetcher(start, end)  # new block replaces old
#     235 self.start = start
#     236 self.end = self.start + len(self.cache)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/s3fs/core.py:2303, in S3File._fetch_range(self, start, end)
#    2301 def _fetch_range(self, start, end):
#    2302     try:
# -> 2303         return _fetch_range(
#    2304             self.fs,
#    2305             self.bucket,
#    2306             self.key,
#    2307             self.version_id,
#    2308             start,
#    2309             end,
#    2310             req_kw=self.req_kw,
#    2311         )
#    2313     except OSError as ex:
#    2314         if ex.args[0] == errno.EINVAL and "pre-conditions" in ex.args[1]:
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/s3fs/core.py:2465, in _fetch_range(fs, bucket, key, version_id, start, end, req_kw)
#    2463     return b""
#    2464 logger.debug("Fetch: %s/%s, %s-%s", bucket, key, start, end)
# -> 2465 return sync(fs.loop, _inner_fetch, fs, bucket, key, version_id, start, end, req_kw)
#
# File ~/miniconda3/envs/scprint/lib/python3.10/site-packages/fsspec/asyn.py:91, in sync(loop, func, timeout, *args, **kwargs)
#      88 asyncio.run_coroutine_threadsafe(_runner(event, coro, result, timeout), loop)
#      89 while True:
#      90     # this loops allows thread to get interrupted
# ---> 91     if event.wait(1):
#      92         break
#      93     if timeout is not None:
#
# File ~/miniconda3/envs/scprint/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/miniconda3/envs/scprint/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
list(ln.Artifact.filter(version="3"))
# Out:
# [Artifact(uid='Mgilie8RUip2slElOmPq', version='3', is_latest=True, description='scPRINT-V2 datasets', suffix='.h5ad', size=489810414, hash='7-paLQLkX3je-5v0oWz7XD', _hash_type='sha1-fl', _accessor='AnnData', visibility=1, _key_is_virtual=True, created_by_id=1, storage_id=1, updated_at='2024-09-18 13:26:29 UTC'),
#  Artifact(uid='iAZPSOBKLpaK7lqyeq5B', version='3', is_latest=True, description='scPRINT-V2 datasets', suffix='.h5ad', size=609504688, hash='ucyfECH2v6qBVTByiQ45Wk', _hash_type='sha1-fl', _accessor='AnnData', visibility=1, _key_is_virtual=True, created_by_id=1, storage_id=1, updated_at='2024-09-18 13:31:43 UTC'),
#  Artifact(uid='8Nvv13lKsjEHL8dndOjz', version='3', is_latest=True, description='scPRINT-V2 datasets', suffix='.h5ad', size=2705747907, hash='vNLVHW_JMWMXgEAtDsvr9a', _hash_type='sha1-fl', _accessor='AnnData', visibility=1, _key_is_virtual=True, created_by_id=1, storage_id=1, updated_at='2024-09-18 13:50:47 UTC'),
#  Artifact(uid='qA6JWwBI3uNVjUqXJECH', version='3', is_latest=True, description='scPRINT-V2 datasets', suffix='.h5ad', size=854708940, hash='0Z2MUnPBkw3B6jCpMSckUG', _hash_type='sha1-fl', _accessor='AnnData', visibility=1, _key_is_virtual=True, created_by_id=1, storage_id=1, updated_at='2024-09-18 13:57:16 UTC'),
#  Artifact(uid='UEE9mPND42ONqZUCGBXy', version='3', is_latest=True, description='scPRINT-V2 datasets', suffix='.h5ad', size=1248097203, hash='ra3V8C0j6ygPDoDaW8q5kE', _hash_type='sha1-fl', _accessor='AnnData', visibility=1, _key_is_virtual=True, created_by_id=1, storage_id=1, updated_at='2024-09-18 14:10:03 UTC')]

# %%
len([i for i in cx_dataset_2.artifacts.filter() if i.is_latest])
# Out:
# 430

# %%
cx_dataset_2.artifacts.filter()[3].open().obs.is_primary_data.sum()
# Out:
# 0
